# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
import requests

# %matplotlib inline

# %%
# Таблица цен на дома в Бостоне

# Основные значения:

# CRIM: This is the per capita crime rate by town
# ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# INDUS: This is the proportion of non-retail business acres per town.
# CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# NOX: This is the nitric oxides concentration (parts per 10 million)
# RM: This is the average number of rooms per dwelling
# AGE: This is the proportion of owner-occupied units built prior to 1940
# DIS: This is the weighted distances to five Boston employment centers
# RAD: This is the index of accessibility to radial highways
# TAX: This is the full-value property-tax rate per 10,000 dollars
# PTRATIO: This is the pupil-teacher ratio by town
# B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# LSTAT: This is the percentage lower status of the population
# MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?

# Нормальное
# Равномерное
# Биноминальное
# Бернулли
# Геометрическое
# Логнормальное

# %%
# Сделать частотный график колонки CRIM. Какое это распределение?
plt.hist(data['CRIM'])
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки CRIM')
plt.grid(True)
plt.show()

print('Распределение близко к геометрическому')
# Out:
# Распределение близко к геометрическому

# %%
# Сделать частотный график колонки ZN. Какое это распределение?
plt.hist(data['ZN'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки ZN')
plt.grid(True)
plt.show()

print('Распределение близко к геометрическому')
# Out:
# Распределение близко к геометрическому

# %%
# Сделать частотный график колонки INDUS. Какое это распределение?
plt.hist(data['INDUS'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки INDUS')
plt.grid(True)
plt.show()

print('Распределение близко к двумодальному (не нашел другого варианта)')
# Out:
# Распределение близко к двумодальному (не нашел другого варианта)

# %%
# Сделать частотный график колонки CHAS. Какое это распределение?
plt.hist(data['CHAS'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки CHAS')
plt.grid(True)
plt.show()

print('Распределение близко к распределению Бернулли')
# Out:
# Распределение близко к распределению Бернулли

# %%
# Сделать частотный график колонки RM. Какое это распределение?
plt.hist(data['RM'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки RM')
plt.grid(True)
plt.show()

print('Распределение близко к нормальному')
# Out:
# Распределение близко к нормальному

# %%
# Сделать частотный график колонки AGE. Какое это распределение?
plt.hist(data['AGE'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки AGE')
plt.grid(True)
plt.show()

print('Распределение близко к логарифмически-нормальному')
# Out:
# Распределение близко к логарифмически-нормальному

# %%
# Сделать частотный график колонки DIS. Какое это распределение?
plt.hist(data['DIS'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки DIS')
plt.grid(True)
plt.show()

print('Распределение близко к равномерному')
# Out:
# Распределение близко к равномерному

# %%
# Сделать частотный график колонки RAD. Какое это распределение?
plt.hist(data['RAD'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки RAD')
plt.grid(True)
plt.show()

print('Нет версий')
# Out:
# Нет версий

# %%
# Сделать частотный график колонки TAX. Какое это распределение?
plt.hist(data['TAX'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки TAX')
plt.grid(True)
plt.show()

print('Нет версий')
# Out:
# Нет версий

# %%
# Сделать частотный график колонки PTRATIO. Какое это распределение?
plt.hist(data['PTRATIO'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки PTRATIO')
plt.grid(True)
plt.show()

print('Здесь даже версий нет')
# Out:
# Здесь даже версий нет

# %%
# Сделать частотный график колонки DIS. Какое это распределение?
plt.hist(data['DIS'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки DIS')
plt.grid(True)
plt.show()

print('Распределение близко к равномерному')
# Out:
# Распределение близко к равномерному

# %%
# Сделать частотный график колонки B. Какое это распределение?
plt.hist(data['B'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки B')
plt.grid(True)
plt.show()

print('Распределение близко к геометрическому')
# Out:
# Распределение близко к геометрическому

# %%
# Сделать частотный график колонки LSTAT. Какое это распределение?
plt.hist(data['LSTAT'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки LSTAT')
plt.grid(True)
plt.show()

print('Распределение близко к логарифмически-нормальному')
# Out:
# Распределение близко к логарифмически-нормальному

# %%
# Сделать частотный график колонки MEDV. Какое это распределение?
plt.hist(data['MEDV'],10)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график выборки MEDV')
plt.grid(True)
plt.show()

print('Распределение близко к нормальному')
# Out:
# Распределение близко к нормальному

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
df=pd.read_csv(url)
df.head(10)

# Загрузить таблицу Happiness report. Нарисовать матрицу ковариаций попарно.
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
# 5      Switzerland       6            11             44.0             21.0
# 6           Sweden       7            18             34.0              8.0
# 7      New Zealand       8            15             22.0             12.0
# 8           Canada       9            23             18.0             49.0
# 9          Austria      10            10             64.0             24.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
# 5            13.0     11.0         7.0        16.0                     8.0
# 6            25.0     10.0         6.0        17.0                    13.0
# 7             5.0      8.0         5.0         8.0                    26.0
# 8            20.0      9.0        11.0        14.0                    19.0
# 9            31.0     26.0        19.0        25.0                    16.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0
# 5                       4.0
# 6                      17.0
# 7                      14.0
# 8                       8.0
# 9                      15.0

# %%
sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("Country(region)")
g = sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-45019471539d> in <module>()
#       1 sns.set(style="ticks", color_codes=True)
# ----> 2 iris = sns.load_dataset("Country(region)")
#       3 g = sns.pairplot(df)
#
# D:\Anaconda\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     408                                   os.path.basename(full_path))
#     409         if not os.path.exists(cache_path):
# --> 410             urlretrieve(full_path, cache_path)
#     411         full_path = cache_path
#     412
#
# D:\Anaconda\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# D:\Anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# D:\Anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# D:\Anaconda\lib\urllib\request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# D:\Anaconda\lib\urllib\request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# D:\Anaconda\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# D:\Anaconda\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
fig = sns.pairplot(data=df, hue='Country (region)')
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=data, hue='species')
plt.show()

# %%
sns.regplot(x= df['Ladder'], y=df['Positive affect'],data=df, fit_reg=True)
plt.xlabel('Степень свободы в стране')
plt.ylabel('Количество счастливых людей')
plt.title('Корреляционная зависимость двух выборок')
plt.grid(False)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-6521b617bbe1> in <module>()
# ----> 1 df['0']
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# D:\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'

# %%
# Напишите код для моделирования 10 подбрасываний игрального кубика. 
# Начертите диаграму histogram. Какое это распределение?
import random

result = list()
i = 0
while i < 10:
    x = random.randint(1, 6)    
    result.append(x)
    i += 1
print(result)
# Out:
# [5, 2, 6, 3, 5, 1, 1, 5, 2, 3]

# %%
plt.hist(result, 6)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график кубика')
plt.grid(True)
plt.show()

# %%
print("Это похоже на равномерное распределение")
# Out:
# Это похоже на равномерное распределение

# %%
# Напишите код для моделирования 1000 подбрасываний игрального кубика. 
# Начертите диаграму histogram. Почему график изменился? 
# Как применить центральную предельную теорему?


result = list()
i = 0
while i < 1000:
    x = random.randint(1, 6)    
    result.append(x)
    i += 1
print(result)
# Out:
, 5, 4, 3, 1, 2, 4, 3, 1, 2, 6, 5, 1, 5, 2, 4, 1, 5, 1, 2, 6, 1, 5, 3, 2, 3, 4, 4, 4, 4, 1, 6, 1, 5, 1, 1, 1, 5, 6, 4, 1, 3, 5, 4, 1, 6, 4, 6, 5, 1, 3, 2, 3, 5, 2, 2, 3, 5, 4, 5, 4, 6, 4, 2, 3, 5, 6, 3, 1, 5, 1, 6, 5, 4, 2, 1, 4, 2, 1, 4, 2, 6, 4, 4, 2, 1, 2, 5, 4, 3, 2, 1, 1, 3, 6, 5, 4, 1, 5, 2, 6, 6, 3, 5, 4, 3, 1, 1, 3, 2, 4, 5, 4, 4, 5, 3, 3, 3, 3, 6, 6, 5, 4, 3, 1, 5, 1, 4, 5, 4, 1, 5, 6, 2, 2, 1, 3, 1, 5, 2, 6, 2, 4, 4, 6, 5, 6, 4, 4, 4, 4, 1, 6, 2, 1, 6, 1, 2, 3, 6, 3, 5, 1, 6, 5, 5, 4, 5, 2, 1, 1, 4, 1, 4, 5, 2, 1, 1, 4, 4, 3, 1, 2, 6, 3, 1, 2, 4, 6, 6, 1, 3, 5, 4, 4, 2, 1, 3, 2, 3, 5, 6, 1, 1, 3, 3, 6, 5, 5, 2, 4, 1, 6, 2, 2, 5, 6, 5, 2, 1, 6, 5, 5, 5, 2, 2, 3, 1, 1, 3, 4, 6, 5, 6, 6, 5, 5, 4, 2, 3, 5, 1, 4, 3, 2, 5, 2, 6, 3, 6, 1, 1, 2, 6, 5, 1, 5, 5, 3, 4, 6, 5, 6, 2, 6, 3, 3, 2, 4, 1, 6, 3, 5, 3, 4, 4, 3, 5, 3, 6, 5, 6, 5, 2, 3, 3, 4, 5, 2, 6, 4, 5, 2, 2, 1, 6, 1, 3, 4, 1, 4, 4, 4, 6, 2, 2, 6, 6, 1, 2, 5, 2, 6, 6, 5, 5, 4, 4, 1, 2, 1, 5, 6, 2, 5, 3, 5, 1, 4, 2, 6, 5, 1, 4, 5, 1, 4, 4, 5, 6, 6, 3, 3, 5, 3, 4, 6, 6, 6, 1, 3, 1, 6, 6, 5, 3, 2, 3, 6, 2, 1, 1, 3, 2, 3, 2, 1, 6, 5, 2, 1, 6, 1, 4, 1, 2, 4, 5, 5, 4, 4, 6, 2, 1, 3, 1, 3, 2, 1, 5, 5, 1, 5, 3, 5, 1, 5, 3, 6, 2, 6, 2, 5, 2, 3, 2, 4, 1, 4, 2, 4, 5, 3, 4, 2, 1, 2, 5, 1, 2, 3, 3, 1, 6, 6, 6, 2, 3, 5, 3, 6, 6, 3, 2, 6, 2, 4, 1, 4, 5, 2, 3]

# %%
plt.hist(result, 6)
plt.xlabel('интервал выборки')
plt.ylabel('количество элементов')
plt.title('Частотный график кубика')
plt.grid(True)
plt.show()

# %%
print("Это похоже на равномерное распределение, график не изменился. Для перевода равномерного распределения в нормальное можно воспользоваться методом полярных координат")
# Out:
# Это похоже на равномерное распределение, график не изменился. Для перевода равномерного распределения в нормальное можно воспользоваться методом полярных координат
